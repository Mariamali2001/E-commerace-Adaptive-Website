# %% [markdown]
# # Notebook 05 – Default UI Repository
#
# Build the **default UI repository** directly from the cleaned survey.
#
# - No machine learning
# - No association rules
# - No clustering
#
# For every UI element, the default is the **majority preference** (most selected option).
# These defaults are the base interface the website loads before applying any adaptations.

# %% [markdown]
# ## Expected Outputs
#
# **JSON (website):**
# - `data/outputs/global_defaults.json`
# - `data/outputs/desktop_defaults.json`
# - `data/outputs/mobile_defaults.json`
#
# **Tables / figures:**
# - `reports/DefaultUI/global_defaults.xlsx`
# - `reports/DefaultUI/desktop_defaults.xlsx`
# - `reports/DefaultUI/mobile_defaults.xlsx`
# - `reports/DefaultUI/figures/`

# %%
import logging
import sys
from pathlib import Path

import matplotlib.pyplot as plt
import pandas as pd


def _bootstrap_project() -> Path:
    search_from = Path.cwd().resolve()
    candidates = [search_from, *search_from.parents]
    nested_root = search_from / "EvidenceBasedAdaptiveUI"
    if (nested_root / "src" / "config.py").exists():
        candidates.insert(0, nested_root)
    for candidate in candidates:
        if (candidate / "src" / "config.py").exists():
            root = str(candidate)
            if root not in sys.path:
                sys.path.insert(0, root)
            return candidate
    raise FileNotFoundError("Could not find project root containing src/config.py.")


PROJECT_ROOT = _bootstrap_project()

from src.default_ui.repository import run_default_ui_repository
from src.preprocessing.columns import (
    DESKTOP_UI_COLUMNS,
    GLOBAL_UI_COLUMNS,
    MOBILE_UI_COLUMNS,
)
from src.utils.notebook import setup_notebook

logging.basicConfig(level=logging.INFO, format="%(levelname)s: %(message)s")
logger = logging.getLogger(__name__)
plt.rcParams["figure.dpi"] = 200

PATHS, REPORTS = setup_notebook("DefaultUI")
OUTPUT_DIR = PATHS.data_outputs

print(f"Reports: {REPORTS}")
print(f"JSON output: {OUTPUT_DIR}")
# Out:
# Reports: /Users/mariam/Downloads/Trial-Guide/EvidenceBasedAdaptiveUI/reports/DefaultUI
# JSON output: /Users/mariam/Downloads/Trial-Guide/EvidenceBasedAdaptiveUI/data/outputs

# %% [markdown]
# ## Load Clean Dataset

# %%
df = pd.read_csv(PATHS.data_processed / "clean_dataset.csv")
print(f"Respondents: {len(df)}")
display(df.head(3))
# Out:
# Respondents: 200
#              timestamp consent age_group  gender education_level  \
# 0  20/01/2026 17:24:30     Yes     18-24    Male        Graduate
# 1  20/01/2026 17:27:08     Yes     25-34  Female        Graduate
# 2  20/01/2026 17:38:38     Yes     18-24    Male        Graduate
#
#   primary_device                                shopping_motivation  \
# 0     Smartphone  Research (I like exploring products and learni...
# 1     Smartphone      Deal-hunting (I look for sales and discounts)
# 2     Smartphone     Entertainment (I browse for fun and enjoyment)
#
#                                       decision_speed  \
# 0          Quick (5-15 minutes - I know what I want)
# 1  Moderate (15-30 minutes - I compare a few opti...
# 2  Impulsive (Less than 5 minutes - I decide quic...
#
#                                    price_sensitivity  \
# 0  Moderately important (I balance price and qual...
# 1  Moderately important (I balance price and qual...
# 2  Somewhat unimportant (Price matters but isn't ...
#
#                                    review_importance  ... Extraversion  \
# 0  Sometimes read reviews (For certain product ty...  ...          3.0
# 1            Often read reviews (For most purchases)  ...          3.5
# 2  Sometimes read reviews (For certain product ty...  ...          4.0
#
#   Agreeableness Conscientiousness  Neuroticism  Openness Extraversion_Level  \
# 0           3.0               3.0          3.0       3.0             Medium
# 1           4.5               3.5          2.5       2.5             Medium
# 2           3.0               3.0          3.5       3.0               High
#
#   Agreeableness_Level Conscientiousness_Level Neuroticism_Level Openness_Level
# 0              Medium                  Medium            Medium         Medium
# 1                High                  Medium               Low            Low
# 2              Medium                  Medium            Medium         Medium
#
# [3 rows x 79 columns]

# %% [markdown]
# ## Step 1 — Separate UI Variables
#
# Global UI · Desktop UI · Mobile UI

# %%
print(f"Global UI variables ({len(GLOBAL_UI_COLUMNS)}):")
for column in GLOBAL_UI_COLUMNS:
    print(f"  - {column}")

print(f"\nDesktop UI variables ({len(DESKTOP_UI_COLUMNS)}):")
for column in DESKTOP_UI_COLUMNS:
    print(f"  - {column}")

print(f"\nMobile UI variables ({len(MOBILE_UI_COLUMNS)}):")
for column in MOBILE_UI_COLUMNS:
    print(f"  - {column}")
# Out:
# Global UI variables (14):
#   - font_style_pref
#   - font_size_pref
#   - color_theme_pref
#   - accent_color_pref
#   - background_pref
#   - whitespace_pref
#   - button_style_pref
#   - hero_banner_size
#   - recommendation_type
#   - social_proof_display
#   - urgency_pref
#   - checkout_style
#   - form_field_style
#   - product_desc_length
#
# Desktop UI variables (13):
#   - desktop_grid_pref
#   - desktop_info_density
#   - desktop_image_text_ratio
#   - desktop_whitespace
#   - desktop_navigation
#   - desktop_search_visibility
#   - desktop_category_display
#   - desktop_product_card
#   - desktop_price_display
#   - desktop_filter_location
#   - desktop_persistent_filters
#   - desktop_quick_view
#   - desktop_review_display
#
# Mobile UI variables (14):
#   - mobile_grid_pref
#   - mobile_info_density
#   - mobile_image_text_ratio
#   - mobile_whitespace
#   - mobile_navigation
#   - mobile_search_visibility
#   - mobile_category_display
#   - mobile_product_card
#   - mobile_price_display
#   - mobile_filter_location
#   - mobile_quick_view
#   - mobile_review_display
#   - mobile_sticky_header
#   - mobile_touch_size

# %% [markdown]
# ## Steps 2–4 — Majority Defaults + Export
#
# For every UI variable: most selected option, percentage, and participant count.

# %%
result = run_default_ui_repository(df, OUTPUT_DIR, REPORTS)

global_defaults = result.tables["Global"]
desktop_defaults = result.tables["Desktop"]
mobile_defaults = result.tables["Mobile"]

print("Global Defaults")
display(global_defaults)

print("Desktop Defaults")
display(desktop_defaults)

print("Mobile Defaults")
display(mobile_defaults)
# Out:
# INFO: Default UI repository: Global=14 Desktop=13 Mobile=14
# Global Defaults
#               UI_Element                                      Default_Value  \
# 0        font_style_pref  2. Classic Serif (Traditional fonts with decor...
# 1         font_size_pref     3. Large (16-18px - Easy to read, comfortable)
# 2       color_theme_pref  Minimalist Black & White (Clean, high contrast...
# 3      accent_color_pref             Blue (Trustworthy, professional, calm)
# 4        background_pref    Cream/Off-white (Warm, comfortable, paper-like)
# 5        whitespace_pref  Balanced (Moderate spacing - comfortable middl...
# 6      button_style_pref       Rounded Corners (Soft, modern rounded edges)
# 7       hero_banner_size            Medium Split (Takes up half the screen)
# 8    recommendation_type         Deals (Products on sale or special offers)
# 9   social_proof_display         User Photos (Photos uploaded by customers)
# 10          urgency_pref      Both (Show both stock and time based urgency)
# 11        checkout_style  One Page (All checkout steps on a single scrol...
# 12      form_field_style  Rounded Border Fields (Outlined field with rou...
# 13   product_desc_length  Expandable Sections (Organized into collapsibl...
#
#     Percentage  Count  Total_Responses  Unique_Options
# 0         36.5     73              200               4
# 1         48.0     96              200               4
# 2         24.5     49              200               6
# 3         60.5    121              200               7
# 4         36.0     72              200               5
# 5         73.5    147              200               3
# 6         41.5     83              200               6
# 7         53.5    107              200               4
# 8         47.0     94              200               4
# 9         36.5     73              200               5
# 10        32.5     65              200               5
# 11        38.5     77              200               5
# 12        24.5     49              200               8
# 13        35.0     70              200               4
# Desktop Defaults
#                     UI_Element  \
# 0            desktop_grid_pref
# 1         desktop_info_density
# 2     desktop_image_text_ratio
# 3           desktop_whitespace
# 4           desktop_navigation
# 5    desktop_search_visibility
# 6     desktop_category_display
# 7         desktop_product_card
# 8        desktop_price_display
# 9      desktop_filter_location
# 10  desktop_persistent_filters
# 11          desktop_quick_view
# 12      desktop_review_display
#
#                                         Default_Value  Percentage  Count  \
# 0       3 Columns (Balanced view, moderate item size)        33.5     67
# 1   Moderate (Balanced - some details visible, cli...        72.5    145
# 2   Image-focused (80% images, 20% text - highly v...        53.5    107
# 3                                            Balanced        57.0    114
# 4   Top Bar (Categories always visible across the ...        29.5     59
# 5   Always Visible Top (Large, prominent search ba...        43.0     86
# 6            Visual Grid (Category tiles with images)        42.5     85
# 7   Info Rich (Lots of details, ratings, specs vis...        30.0     60
# 8   With Savings Highlighted (Shows discount amoun...        26.5     53
# 9   Sidebar Left (Permanent filter panel on the le...        45.5     91
# 10          Yes (Always visible sidebar with filters)        75.0    150
# 11    Sidebar Slide (Details slide in from the right)        48.0     96
# 12            Recent 3- 5 (Show a few recent reviews)        39.0     78
#
#     Total_Responses  Unique_Options
# 0               200               5
# 1               200               3
# 2               200               3
# 3               200               3
# 4               200               4
# 5               200               3
# 6               200               4
# 7               200               5
# 8               200               5
# 9               200               3
# 10              200               2
# 11              200               4
# 12              200               4
# Mobile Defaults
#                   UI_Element  \
# 0           mobile_grid_pref
# 1        mobile_info_density
# 2    mobile_image_text_ratio
# 3          mobile_whitespace
# 4          mobile_navigation
# 5   mobile_search_visibility
# 6    mobile_category_display
# 7        mobile_product_card
# 8       mobile_price_display
# 9     mobile_filter_location
# 10         mobile_quick_view
# 11     mobile_review_display
# 12      mobile_sticky_header
# 13         mobile_touch_size
#
#                                         Default_Value  Percentage  Count  \
# 0    Compact stacked cards (more products per screen)        47.0     94
# 1   Moderate (Balanced - some details visible, cli...        68.5    137
# 2    Balanced (50% images, 50% text - equal emphasis)        83.0    166
# 3                                            Balanced        85.0    170
# 4   Bottom Nav (Navigation bar at the bottom - mob...        50.0    100
# 5   Collapsible (Search bar that expands when clic...        39.5     79
# 6            Dropdown Menu (Text-based dropdown list)        42.5     85
# 7   Info Rich (Lots of details, ratings, specs vis...        39.0     78
# 8   Strike-through Original (Shows original price ...        62.5    125
# 9   Drawer Overlay (Slides in from the side when c...        58.0    116
# 10  Slide-Up Panel (Preview product details in a s...        52.0    104
# 11  Collapsible Sections (Reviews can be expanded ...        53.0    106
# 12          Yes (Header stays at top while scrolling)        64.5    129
# 13       Standard (Normal size, more content visible)        55.5    111
#
#     Total_Responses  Unique_Options
# 0               200               4
# 1               200               3
# 2               200               3
# 3               200               3
# 4               200               4
# 5               200               3
# 6               200               3
# 7               200               5
# 8               200               3
# 9               200               3
# 10              200               3
# 11              200               3
# 12              200               2
# 13              200               3

# %% [markdown]
# ## Visualizations
#
# Top selected options and preference distributions.

# %%
from IPython.display import Image, display as ipy_display

figures_dir = REPORTS / "figures"
for figure_name in [
    "global_top_selected_options.png",
    "desktop_top_selected_options.png",
    "mobile_top_selected_options.png",
    "global_strongest_distribution.png",
    "desktop_strongest_distribution.png",
    "mobile_strongest_distribution.png",
]:
    figure_path = figures_dir / figure_name
    if figure_path.exists():
        print(figure_name)
        ipy_display(Image(filename=str(figure_path)))
# Out:
# global_top_selected_options.png
# desktop_top_selected_options.png
# mobile_top_selected_options.png
# global_strongest_distribution.png
# desktop_strongest_distribution.png
# mobile_strongest_distribution.png

# %% [markdown]
# ## Exports

# %%
print("Export locations:")
for name, path in result.export_paths.items():
    print(f"- {name}: {path}")
# Out:
# Export locations:
# - global_defaults_json: /Users/mariam/Downloads/Trial-Guide/EvidenceBasedAdaptiveUI/data/outputs/global_defaults.json
# - global_defaults_xlsx: /Users/mariam/Downloads/Trial-Guide/EvidenceBasedAdaptiveUI/reports/DefaultUI/global_defaults.xlsx
# - global_defaults_csv: /Users/mariam/Downloads/Trial-Guide/EvidenceBasedAdaptiveUI/reports/DefaultUI/global_defaults.csv
# - desktop_defaults_json: /Users/mariam/Downloads/Trial-Guide/EvidenceBasedAdaptiveUI/data/outputs/desktop_defaults.json
# - desktop_defaults_xlsx: /Users/mariam/Downloads/Trial-Guide/EvidenceBasedAdaptiveUI/reports/DefaultUI/desktop_defaults.xlsx
# - desktop_defaults_csv: /Users/mariam/Downloads/Trial-Guide/EvidenceBasedAdaptiveUI/reports/DefaultUI/desktop_defaults.csv
# - mobile_defaults_json: /Users/mariam/Downloads/Trial-Guide/EvidenceBasedAdaptiveUI/data/outputs/mobile_defaults.json
# - mobile_defaults_xlsx: /Users/mariam/Downloads/Trial-Guide/EvidenceBasedAdaptiveUI/reports/DefaultUI/mobile_defaults.xlsx
# - mobile_defaults_csv: /Users/mariam/Downloads/Trial-Guide/EvidenceBasedAdaptiveUI/reports/DefaultUI/mobile_defaults.csv
# - global_top_options: /Users/mariam/Downloads/Trial-Guide/EvidenceBasedAdaptiveUI/reports/DefaultUI/figures/global_top_selected_options.png
# - global_strongest_distribution: /Users/mariam/Downloads/Trial-Guide/EvidenceBasedAdaptiveUI/reports/DefaultUI/figures/global_strongest_distribution.png
# - global_weakest_distribution: /Users/mariam/Downloads/Trial-Guide/EvidenceBasedAdaptiveUI/reports/DefaultUI/figures/global_weakest_distribution.png
# - desktop_top_options: /Users/mariam/Downloads/Trial-Guide/EvidenceBasedAdaptiveUI/reports/DefaultUI/figures/desktop_top_selected_options.png
# - desktop_strongest_distribution: /Users/mariam/Downloads/Trial-Guide/EvidenceBasedAdaptiveUI/reports/DefaultUI/figures/desktop_strongest_distribution.png
# - desktop_weakest_distribution: /Users/mariam/Downloads/Trial-Guide/EvidenceBasedAdaptiveUI/reports/DefaultUI/figures/desktop_weakest_distribution.png
# - mobile_top_options: /Users/mariam/Downloads/Trial-Guide/EvidenceBasedAdaptiveUI/reports/DefaultUI/figures/mobile_top_selected_options.png
# - mobile_strongest_distribution: /Users/mariam/Downloads/Trial-Guide/EvidenceBasedAdaptiveUI/reports/DefaultUI/figures/mobile_strongest_distribution.png
# - mobile_weakest_distribution: /Users/mariam/Downloads/Trial-Guide/EvidenceBasedAdaptiveUI/reports/DefaultUI/figures/mobile_weakest_distribution.png
# - summary_md: /Users/mariam/Downloads/Trial-Guide/EvidenceBasedAdaptiveUI/reports/DefaultUI/default_ui_summary.md

# %% [markdown]
# ## Final Output

# %%
print(f"Global variables: {result.summary['global_variables']}")
print(f"Desktop variables: {result.summary['desktop_variables']}")
print(f"Mobile variables: {result.summary['mobile_variables']}")
print("Repository generated successfully.")
# Out:
# Global variables: 14
# Desktop variables: 13
# Mobile variables: 14
# Repository generated successfully.
