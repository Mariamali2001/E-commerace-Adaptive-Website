# %% [markdown]
# # Notebook 01 – Data Cleaning & Preprocessing
#
# **Evidence-Based Adaptive User Interface Framework for E-Commerce**
#
# ### Objectives
# - Load raw survey data
# - Validate integrity
# - Remove invalid responses
# - Verify attention check
# - Handle missing values
# - Standardize column names
# - Export clean dataset

# %% [markdown]
# ## Expected Outputs
# - `data/processed/clean_dataset.csv`
# - `reports/01_data_cleaning/data_quality_summary.xlsx`
# - `reports/01_data_cleaning/data_cleaning_report.md`

# %%
import logging
import sys
from pathlib import Path

import pandas as pd


def _bootstrap_project() -> Path:
    search_from = Path.cwd().resolve()
    candidates = [search_from, *search_from.parents]
    nested_root = search_from / "EvidenceBasedAdaptiveUI"
    if (nested_root / "src" / "config.py").exists():
        candidates.insert(0, nested_root)

    for candidate in candidates:
        if (candidate / "src" / "config.py").exists():
            root = str(candidate)
            if root not in sys.path:
                sys.path.insert(0, root)
            return candidate

    raise FileNotFoundError(
        "Could not find project root containing src/config.py. "
        "Open EvidenceBasedAdaptiveUI (or its parent workspace) and rerun."
    )


_bootstrap_project()
from src.preprocessing.cleaning import (
    add_big_five_levels,
    categorical_quality_report,
    compute_big_five_scores,
    dataset_summary,
    drop_bfi10_raw_columns,
    filter_attention_checks,
    standardize_column_names,
)
from src.utils.notebook import setup_notebook

logging.basicConfig(level=logging.INFO, format="%(levelname)s: %(message)s")

PATHS, REPORTS = setup_notebook("01_data_cleaning")
RAW_DATA = PATHS.data_raw / "E-Commerce - data.csv"
PROCESSED = PATHS.data_processed

# %% [markdown]
# ## Load Dataset

# %%
df = pd.read_csv(RAW_DATA)
print(df.shape)
display(df.head())
df.columns
# Out:
# (240, 74)
#              Timestamp consent age_group  gender education_level  \
# 0  20/01/2026 17:24:30     Yes     18-24    Male        Graduate
# 1  20/01/2026 17:27:08     Yes     25-34  Female        Graduate
# 2  20/01/2026 17:37:31     Yes     25-34  Female        Graduate
# 3  20/01/2026 17:38:38     Yes     18-24    Male        Graduate
# 4  20/01/2026 17:41:19     Yes     25-34  Female    Postgraduate
#
#   primary_device                                shopping_motivation  \
# 0     Smartphone  Research (I like exploring products and learni...
# 1     Smartphone      Deal-hunting (I look for sales and discounts)
# 2     Smartphone             Gift-buying (I mainly shop for others)
# 3     Smartphone     Entertainment (I browse for fun and enjoyment)
# 4     Smartphone  Need-based (I shop when I need something speci...
#
#                                       decision_speed  \
# 0          Quick (5-15 minutes - I know what I want)
# 1  Moderate (15-30 minutes - I compare a few opti...
# 2  Moderate (15-30 minutes - I compare a few opti...
# 3  Impulsive (Less than 5 minutes - I decide quic...
# 4  Research-heavy (30+ minutes - I thoroughly res...
#
#                                    price_sensitivity  \
# 0  Moderately important (I balance price and qual...
# 1  Moderately important (I balance price and qual...
# 2  Moderately important (I balance price and qual...
# 3  Somewhat unimportant (Price matters but isn't ...
# 4  Moderately important (I balance price and qual...
#
#                                    review_importance  ...  \
# 0  Sometimes read reviews (For certain product ty...  ...
# 1            Often read reviews (For most purchases)  ...
# 2  Always read reviews (I won't buy without check...  ...
# 3  Sometimes read reviews (For certain product ty...  ...
# 4            Often read reviews (For most purchases)  ...
#
#                                 mobile_price_display  \
# 0  Strike-through Original (Shows original price ...
# 1  Strike-through Original (Shows original price ...
# 2  Strike-through Original (Shows original price ...
# 3  Simple Display (Price is visible but not empha...
# 4  Simple Display (Price is visible but not empha...
#
#                               mobile_filter_location  \
# 0  Drawer Overlay (Slides in from the side when c...
# 1  Drawer Overlay (Slides in from the side when c...
# 2  Drawer Overlay (Slides in from the side when c...
# 3  Drawer Overlay (Slides in from the side when c...
# 4  Drawer Overlay (Slides in from the side when c...
#
#                                    mobile_quick_view  \
# 0  Slide-Up Panel (Preview product details in a s...
# 1  Slide-Up Panel (Preview product details in a s...
# 2  Slide-Up Panel (Preview product details in a s...
# 3  Slide-Up Panel (Preview product details in a s...
# 4  No Quick View (I prefer to go to the full prod...
#
#                                mobile_review_display  \
# 0  Collapsible Sections (Reviews can be expanded ...
# 1  Collapsible Sections (Reviews can be expanded ...
# 2  Collapsible Sections (Reviews can be expanded ...
# 3      Summary Only (Average rating and total count)
# 4  Collapsible Sections (Reviews can be expanded ...
#
#                         mobile_sticky_header  \
# 0      No (Header scrolls away with content)
# 1  Yes (Header stays at top while scrolling)
# 2  Yes (Header stays at top while scrolling)
# 3  Yes (Header stays at top while scrolling)
# 4  Yes (Header stays at top while scrolling)
#
#                               mobile_touch_size  \
# 0   Large (Easier to tap, less content visible)
# 1  Standard (Normal size, more content visible)
# 2  Standard (Normal size, more content visible)
# 3   Large (Easier to tap, less content visible)
# 4   Large (Easier to tap, less content visible)
#
#                            expects_device_adaptation  adaptation_comfort  \
# 0      Somewhat Different (Adapted but recognizable)                   3
# 1      Somewhat Different (Adapted but recognizable)                   5
# 2  Yes, Very Different (Completely different desi...                   5
# 3      Somewhat Different (Adapted but recognizable)                   4
# 4  Yes, Very Different (Completely different desi...                   5
#
#                                      delight_factors  \
# 0                                                NaN
# 1  the website or the application should be user-...
# 2                                                NaN
# 3  It allows me to buy items new to me and it sav...
# 4         Search bar - filters - colors of the pages
#
#                                   frustration_points
# 0                                                NaN
# 1  when the description or the photo of the produ...
# 2                                                NaN
# 3      Lack of stock or high prices for low quality
# 4  If I can’t sea the prices clearly or no filter...
#
# [5 rows x 74 columns]
# Index(['Timestamp', 'consent', 'age_group', 'gender', 'education_level',
#        'primary_device', 'shopping_motivation', 'decision_speed',
#        'price_sensitivity', 'review_importance', 'brand_loyalty',
#        'social_proof_influence', 'primary_persona', 'check1',
#        'trait_introversion', 'trait_trust', 'trait_low_conscientiousness',
#        'trait_emotional_stability', 'check2', 'trait_low_openness',
#        'trait_extraversion', 'trait_agreeableness_reverse',
#        'trait_conscientiousness', 'trait_neuroticism', 'trait_openness',
#        'current_mood', 'font_style_pref', 'font_size_pref', 'color_theme_pref',
#        'accent_color_pref', 'background_pref', 'whitespace_pref',
#        'button_style_pref', 'hero_banner_size', 'recommendation_type',
#        'social_proof_display', 'urgency_pref', 'check3', 'checkout_style',
#        'form_field_style', 'product_desc_length', 'check4',
#        'desktop_grid_pref', 'desktop_info_density', 'desktop_image_text_ratio',
#        'desktop_whitespace', 'desktop_navigation', 'desktop_search_visibility',
#        'desktop_category_display', 'check5', 'desktop_product_card',
#        'desktop_price_display', 'desktop_filter_location',
#        'desktop_persistent_filters', 'desktop_quick_view',
#        'desktop_review_display', 'mobile_grid_pref', 'mobile_info_density',
#        'mobile_image_text_ratio', 'mobile_whitespace', 'mobile_navigation',
#        'mobile_search_visibility', 'mobile_category_display',
#        'mobile_product_card', 'mobile_price_display', 'mobile_filter_location',
#        'mobile_quick_view', 'mobile_review_display', 'mobile_sticky_header',
#        'mobile_touch_size', 'expects_device_adaptation', 'adaptation_comfort',
#        'delight_factors', 'frustration_points'],
#       dtype='object')

# %% [markdown]
# ## Dataset Quality

# %%
summary = dataset_summary(df)
display(summary)
summary.to_excel(REPORTS / "data_quality_summary.xlsx")
# Out:
#                             dtype  missing  unique
# Timestamp                  object        0     240
# consent                    object        0       1
# age_group                  object        0       4
# gender                     object        0       2
# education_level            object        0       5
# ...                           ...      ...     ...
# mobile_touch_size          object        0       3
# expects_device_adaptation  object        0       4
# adaptation_comfort          int64        0       5
# delight_factors            object       88     149
# frustration_points         object       90     147
#
# [74 rows x 3 columns]

# %% [markdown]
# ## Attention Check

# %%
before = len(df)
df = filter_attention_checks(df)
print(f"Removed {before - len(df)} responses failing attention checks")
print(f"Remaining rows: {len(df)}")
# Out:
# WARNING: Attention column 'attention_check' not found.
# INFO: Removed 40 rows via check1-check5 filters
# Removed 40 responses failing attention checks
# Remaining rows: 200

# %% [markdown]
# ## Duplicate Check

# %%
if "timestamp" in df.columns:
    duplicates = df["timestamp"].duplicated().sum()
    print(f"Duplicate timestamps: {duplicates}")
else:
    print("Timestamp column not found")
# Out:
# Timestamp column not found

# %% [markdown]
# ## Missing Values

# %%
display(df.isna().sum().sort_values(ascending=False))
# Out:
# frustration_points             70
# delight_factors                68
# desktop_navigation              0
# desktop_persistent_filters      0
# desktop_filter_location         0
#                                ..
# trait_openness                  0
# trait_neuroticism               0
# trait_conscientiousness         0
# trait_agreeableness_reverse     0
# check3                          0
# Length: 74, dtype: int64

# %% [markdown]
# ## Standardize Columns

# %%
df = standardize_column_names(df)
print(df.columns.tolist())
# Out:
# ['timestamp', 'consent', 'age_group', 'gender', 'education_level', 'primary_device', 'shopping_motivation', 'decision_speed', 'price_sensitivity', 'review_importance', 'brand_loyalty', 'social_proof_influence', 'primary_persona', 'check1', 'trait_introversion', 'trait_trust', 'trait_low_conscientiousness', 'trait_emotional_stability', 'check2', 'trait_low_openness', 'trait_extraversion', 'trait_agreeableness_reverse', 'trait_conscientiousness', 'trait_neuroticism', 'trait_openness', 'current_mood', 'font_style_pref', 'font_size_pref', 'color_theme_pref', 'accent_color_pref', 'background_pref', 'whitespace_pref', 'button_style_pref', 'hero_banner_size', 'recommendation_type', 'social_proof_display', 'urgency_pref', 'check3', 'checkout_style', 'form_field_style', 'product_desc_length', 'check4', 'desktop_grid_pref', 'desktop_info_density', 'desktop_image_text_ratio', 'desktop_whitespace', 'desktop_navigation', 'desktop_search_visibility', 'desktop_category_display', 'check5', 'desktop_product_card', 'desktop_price_display', 'desktop_filter_location', 'desktop_persistent_filters', 'desktop_quick_view', 'desktop_review_display', 'mobile_grid_pref', 'mobile_info_density', 'mobile_image_text_ratio', 'mobile_whitespace', 'mobile_navigation', 'mobile_search_visibility', 'mobile_category_display', 'mobile_product_card', 'mobile_price_display', 'mobile_filter_location', 'mobile_quick_view', 'mobile_review_display', 'mobile_sticky_header', 'mobile_touch_size', 'expects_device_adaptation', 'adaptation_comfort', 'delight_factors', 'frustration_points']

# %% [markdown]
# ## Categorical Validation

# %%
quality_df = categorical_quality_report(df)
display(quality_df)
quality_df.to_excel(REPORTS / "categorical_quality_summary.xlsx", index=False)
# Out:
#                         column  unique_values  missing
# 0                    timestamp            200        0
# 1                      consent              1        0
# 2                    age_group              4        0
# 3                       gender              2        0
# 4              education_level              5        0
# 5               primary_device              2        0
# 6          shopping_motivation              5        0
# 7               decision_speed              4        0
# 8            price_sensitivity              5        0
# 9            review_importance              5        0
# 10               brand_loyalty              5        0
# 11      social_proof_influence              5        0
# 12             primary_persona              6        0
# 13                current_mood              8        0
# 14             font_style_pref              4        0
# 15              font_size_pref              4        0
# 16            color_theme_pref              6        0
# 17           accent_color_pref              7        0
# 18             background_pref              5        0
# 19             whitespace_pref              3        0
# 20           button_style_pref              6        0
# 21            hero_banner_size              4        0
# 22         recommendation_type              4        0
# 23        social_proof_display              5        0
# 24                urgency_pref              5        0
# 25                      check3              1        0
# 26              checkout_style              5        0
# 27            form_field_style              8        0
# 28         product_desc_length              4        0
# 29           desktop_grid_pref              5        0
# 30        desktop_info_density              3        0
# 31    desktop_image_text_ratio              3        0
# 32          desktop_whitespace              3        0
# 33          desktop_navigation              4        0
# 34   desktop_search_visibility              3        0
# 35    desktop_category_display              4        0
# 36        desktop_product_card              5        0
# 37       desktop_price_display              5        0
# 38     desktop_filter_location              3        0
# 39  desktop_persistent_filters              2        0
# 40          desktop_quick_view              4        0
# 41      desktop_review_display              4        0
# 42            mobile_grid_pref              4        0
# 43         mobile_info_density              3        0
# 44     mobile_image_text_ratio              3        0
# 45           mobile_whitespace              3        0
# 46           mobile_navigation              4        0
# 47    mobile_search_visibility              3        0
# 48     mobile_category_display              3        0
# 49         mobile_product_card              5        0
# 50        mobile_price_display              3        0
# 51      mobile_filter_location              3        0
# 52           mobile_quick_view              3        0
# 53       mobile_review_display              3        0
# 54        mobile_sticky_header              2        0
# 55           mobile_touch_size              3        0
# 56   expects_device_adaptation              4        0
# 57             delight_factors            129       68
# 58          frustration_points            127       70

# %% [markdown]
# ## Big Five Scores

# %%
df = compute_big_five_scores(df)
df = add_big_five_levels(df)
df = drop_bfi10_raw_columns(df)
print(f"Remaining columns: {df.shape[1]}")
# Out:
# Remaining columns: 79

# %% [markdown]
# ## Export

# %%
output = PROCESSED / "clean_dataset.csv"
df.to_csv(output, index=False)

with open(REPORTS / "cleaning_log.txt", "w", encoding="utf-8") as handle:
    handle.write(f"Final rows: {len(df)}\n")
    handle.write(f"Columns: {df.shape[1]}\n")

with open(REPORTS / "data_cleaning_report.md", "w", encoding="utf-8") as handle:
    handle.write("# Data Cleaning Report\n\n")
    handle.write(f"- Final rows: {len(df)}\n")
    handle.write(f"- Final columns: {df.shape[1]}\n")
    handle.write(f"- Output file: `{output}`\n")

print(f"Saved: {output}")
# Out:
# Saved: /Users/mariam/Downloads/Trial-Guide/EvidenceBasedAdaptiveUI/data/processed/clean_dataset.csv
